# %%
balance = 1000
def check_balance():
    global balance
    print('Your balance is: ', balance)
    print('______________________________________________________________________________________________')
def deposit(amount):
    global balance
    balance += amount
    print('Transaction Successful')
    print('______________________________________________________________________________________________')
def withdraw(amount):
    global balance
    if amount <= balance:
        balance -= amount
        print('You have successfully withdrawed ', amount)
        print('______________________________________________________________________________________________')
    elif amount > balance:
        print('Dear', CBNdata[pin],',you have insufficient balance')
        print('______________________________________________________________________________________________')
def buy_airtime(amount):
    global balance
    if amount <= balance:
        balance -= amount
        import random
        airtime = random.randint(10000000000000, 99000000000000)
        phone_no = input('Enter the recipient phone number: ')
        print('Telephone number', phone_no,'has been credited with', amount, 'airtime and your airtime is: ', airtime)
        print('______________________________________________________________________________________________')
    elif amount> balance:
        print('Dear', CBNdata[pin],',you have insufficient balance')
        print('______________________________________________________________________________________________')
def transfer(amount):
    global balance
    if amount <= balance:
        balance -= amount
        account = str(input('Enter the recipient account number: '))
        total = [1,2,3,4,5,6,7,8,9,0] 
        if len(total) == len(account):
            print('Account number', account, 'found')
            print('Transaction successful')
            print('______________________________________________________________________________________________')
        else:
            while True:
                print('Invalid account number')
                account = input('Enter the recipient account number: ')
                total = [1,2,3,4,5,6,7,8,9,0]
                if len(total) == len(account):
                    print('Account number', account, 'found')
                    print('Transaction successful')
                    print('______________________________________________________________________________________________')
                    break
                    
    elif amount>balance:
        print('Dear', CBNdata[pin],',you have insufficient balance')
        print('______________________________________________________________________________________________')
def bill_payment(amount):
    global balance
    if amount <= balance:
        balance -= amount
        import random
        token = random.randint(10000000000000, 990000000000000)
        print('Transaction successful and your token is:',token)
        print('______________________________________________________________________________________________')
    elif amount> balance:
        print('Dear', CBNdata[pin],',you have insufficient balance')
        print('______________________________________________________________________________________________')
def buy_data(amount):
    global balance
    print('1gb is #300, 2gb is #600, 3gb is #900')
    if amount <= balance:
        balance -= amount
        if amount == 300:
            print('You have successfully purchased 1gb')
            print('______________________________________________________________________________________________')
        elif amount == 600:
            print('You have successfully purchased 2gb')
            print('______________________________________________________________________________________________')
        elif amount == 900:
            print('You have successfully purchased 3gb')
            print('______________________________________________________________________________________________')
        else:
            while True:
                print('Invalid entry')
                amount = int(input('Enter amount to purchase:'))
                if amount == 300:
                    print('You have successfully purchased 1gb')
                    print('______________________________________________________________________________________________')
                    break
                elif amount == 600:
                    print('You have successfully purchased 2gb')
                    print('______________________________________________________________________________________________')
                    break
                elif amount == 900:
                    print('You have successfully purchased 3gb')
                    print('______________________________________________________________________________________________')
                    break
    elif amount> balance:
        print('Dear', CBNdata[pin],',you have insufficient balance')
        print('______________________________________________________________________________________________')
def menu():
    print('Press 1----------To Check Balance')
    print('Press 2----------To Make a Deposit')
    print('Press 3----------To Withdraw')
    print('Press 4----------To Buy Airtime')
    print('Press 5----------To Make a Transfer')
    print('Press 6----------For Bill Payment')
    print('Press 7----------To Buy Data')
    print('Press 0----------To Exit')
    print('______________________________________________________________________________________________')
def main(): 
    menu()
    while True:
        choice = input('Enter your choice: ')
        if choice == '1':
            check_balance()
            menu()
        elif choice == '2':
            amount = int(input('Enter amount to deposit: '))
            deposit(amount)
            menu()
        elif choice == '3':
            amount = int(input('Enter amount to withdraw: '))
            withdraw(amount)
            menu()
        elif choice == '4':
            amount = int(input('Enter amount to purchase: '))
            buy_airtime(amount)
            menu()
        elif choice == '5':
            amount = int(input('Enter amount to transfer: '))
            transfer(amount)
            menu()
        elif choice == '6':
            amount = int(input('Enter amount to purchase: '))
            bill_payment(amount)
            menu()
        elif choice == '7':
            print('1gb is #300, 2gb is #600, 3gb is #900')
            amount = int(input('Enter amount to purchase: '))
            buy_data(amount)
            menu()
        elif choice == '0':
            print('Dear', CBNdata[pin],'THANK YOU FOR BANKING WITH US')
            break
        else:
            print('Invalid Entry')
            print('______________________________________________________________________________________________')
            menu()
CBNdata = {'1819':'Israel Adekola',
        '1617':'Michael Adeyinka',
        '1415':'Gbolahan Abdulquoyum',
        '1213':'Agbeke Ridwan',
        '9101':'Olajumoke Sulaimon',
        '5678':'Damilola Kareem',
        '1234':'Folashade Oluwagbemi',
        '0715':'Oke Boluwatife',
        '6981':'Fasola Qosim',
        '8642':'Ogunleye Boluwatife',
        '9012':'James Oluwasanmi',
        '1029':'Odunnuga Emmanuel',
        '5761':'Adelaja Emmanuel',
        '6789':'Idowu Oluwatimilehin',
        '1209':'Masopa Adesewa',
        '0912':'Annabel Oreoluwa',
        '1357':'Toluwalase Tobiloba',
        '2468':'Remilekun Alao'}
print("""
        ########################################################################
        $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
        *                                                                      *
        **                                                                    **
        ***               CEPHAS MULTIPURPOSE BANKING SERVICES               ***
        ****                                                                ****
        *****            (insert your ATM and provide your pin)            *****
        ******                                                            ******
        *******                                                          *******
        $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
        ########################################################################
""")
pin = str(input('Enter your Pin: '))
if pin in CBNdata.keys():
    print('Dear', CBNdata[pin], 'Welcome to Cephas ATM stand')
    print('______________________________________________________________________________________________')
    main()
else:
    for i in range(5, 0, -1):
        print('Wrong pin, you have ', i-1, 'more attempt')
        print('______________________________________________________________________________________________')
        pin = str(input('Enter your Pin: '))
        if pin in CBNdata.keys():
            print('Dear', CBNdata[pin], 'Welcome to Cephas ATM stand')
            print('______________________________________________________________________________________________')
            main()
            break
# Out:
#         ########################################################################
#         $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#         *                                                                      *
#         **                                                                    **
#         ***               CEPHAS MULTIPURPOSE BANKING SERVICES               ***
#         ****                                                                ****
#         *****            (insert your ATM and provide your pin)            *****
#         ******                                                            ******
#         *******                                                          *******
#         $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
#         ########################################################################
#
# Enter your Pin: 6789
# Dear Idowu Oluwatimilehin Welcome to Cephas ATM stand
# ...
